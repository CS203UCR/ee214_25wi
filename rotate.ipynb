# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator  # pylint: disable=import-error, no-name-in-module
from qiskit.visualization import plot_histogram
from qiskit.quantum_info import Statevector
from qiskit_aer import Aer
from qiskit.visualization import array_to_latex
import numpy as np
from qiskit import assemble
from math import pi
from qiskit_textbook.widgets import gate_demo
from qiskit.visualization import plot_bloch_multivector, plot_histogram, array_to_latex

# %% [markdown]
# ## The P-gate

# %%
qc = QuantumCircuit(1)
qc.p(pi/4, 0)
qc.draw(output="latex")
# Out:
# <PIL.Image.Image image mode=RGB size=155x37 at 0x7F192D4FBCD0>

# %%
# Let's see the result
qc.save_statevector()
sim = Aer.get_backend("aer_simulator")
state = sim.run(qc).result().get_statevector()
plot_bloch_multivector(state)

# %% [markdown]
# ## The S-Gate

# %%
qc = QuantumCircuit(1)
qc.s(0)   # Apply S-gate to qubit 0
qc.sdg(0) # Apply Sdg-gate to qubit 0
qc.draw(output="latex")
# Out:
# <PIL.Image.Image image mode=RGB size=171x31 at 0x7F192E7DA400>

# %%
# Let's see the result
qc.save_statevector()
sim = Aer.get_backend("aer_simulator")
state = sim.run(qc).result().get_statevector()
plot_bloch_multivector(state)

# %% [markdown]
# ## The T-Gate

# %%
qc = QuantumCircuit(1)
qc.t(0)   # Apply T-gate to qubit 0
qc.tdg(0) # Apply Tdg-gate to qubit 0
qc.draw(output="latex")
# Out:
# <PIL.Image.Image image mode=RGB size=178x31 at 0x7F192D27D640>

# %%
# Let's see the result
qc.save_statevector()
sim = Aer.get_backend("aer_simulator")
state = sim.run(qc).result().get_statevector()
plot_bloch_multivector(state)

# %% [markdown]
# ## The U-Gate

# %%
# Let's have U-gate transform a |0> to |+> state
qc = QuantumCircuit(1)
qc.u(pi/2, 0, pi, 0)
qc.draw(output="latex")
# Out:
# <PIL.Image.Image image mode=RGB size=198x37 at 0x7F192D4AA280>

# %%
# Let's see the result
qc.save_statevector()
sim = Aer.get_backend("aer_simulator")
state = sim.run(qc).result().get_statevector()
plot_bloch_multivector(state)
